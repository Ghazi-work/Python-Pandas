# %%
import pandas as pd
import seaborn as sns

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic_df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic_df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.heatmap(titanic_df.isnull())
# Out:
# <Axes: >

# %%
titanic_df['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic_df.embark_town.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
titanic_df.embark_town.value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %% [markdown]
# I want to look gender based fare average

# %%
titanic_df.groupby('sex')['fare'].mean()
# Out:
# sex
# female    44.479818
# male      25.523893
# Name: fare, dtype: float64

# %% [markdown]
# I want to look gender, who based fare average

# %%
titanic_df.groupby(['sex', 'who'])['fare'].mean()
# Out:
# sex     who
# female  child    31.302328
#         woman    46.570711
# male    child    34.380522
#         man      24.864182
# Name: fare, dtype: float64

# %% [markdown]
# # More Pandas tips on EDA

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ### Finding the percentage of missing values in a dataset

# %%
titanic_df.isnull().sum() / len(titanic_df) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# ### Handling missing values

# %% [markdown]
# ##### we can handle missing values by:
#
# 1. Dropping the column or those rows
# 2. Filling it with mean, median or mode

# %%
titanic_df.isnull().sum() / len(titanic_df) * 100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# dropping dec column cuz too many missing values

# %%
titanic_df.drop('deck', axis=1, inplace=True)

# %%
titanic_df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'embark_town', 'alive',
#        'alone'],
#       dtype='object')

# %%
titanic_df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# now we will target age column

# %%
print(titanic_df['age'].mean())
print(titanic_df['age'].median())
print(titanic_df['age'].mode()[0])
# Out:
# 29.69911764705882
# 28.0
# 24.0

# %% [markdown]
# We can fill the age missing values by either **Mean** **Median** **Mode**

# %%
titanic_df['age'].fillna(titanic_df['age'].mean(), inplace=True)

# %%
titanic_df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
titanic_df['embarked'].unique()
titanic_df['embark_town'].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %% [markdown]
# I think I see a relation between these two columns its the first letter of the value
#
# I would like to look the rows which are null

# %%
selected_columns = titanic_df[['embarked', 'embark_town']]

# Create a boolean mask for rows with missing values in the selected columns
missing_values_mask = selected_columns.isnull().any(axis=1)

# Use the mask to filter the DataFrame and display only rows with missing values
rows_with_missing_values = selected_columns[missing_values_mask]

# Display the result
print(rows_with_missing_values)
# Out:
#     embarked embark_town
# 61       NaN         NaN
# 829      NaN         NaN

# %%
titanic_df['embarked'].fillna(titanic_df['embarked'].mode()[0], inplace=True)
titanic_df['embark_town'].fillna(
    titanic_df['embark_town'].mode()[0], inplace=True)

# %%
titanic_df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# Creating bins and labels for histogram (Classes for numerical data)

# %%
# 0-5 5-13 13-18 18-25 25-30 30-40 40-50 50+
bins = [0, 5, 13, 18, 25, 30, 40, 50, 60]
labels = ['infant', 'pre-teen', 'teen', 'adult',
          'mature', 'matureII', 'old', 'senior']
titanic_df['Age_classes'] = pd.cut(titanic_df['age'], bins=bins, labels=labels)
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone Age_classes
# 0    man        True  Southampton    no  False       adult
# 1  woman       False    Cherbourg   yes  False    matureII
# 2  woman       False  Southampton   yes   True      mature
# 3  woman       False  Southampton   yes  False    matureII
# 4    man        True  Southampton    no   True    matureII

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(titanic_df['Age_classes'])
plt.title('Histogram of age groups')
plt.xlabel('Age classes')
plt.ylabel('Count')
plt.show()

# %%
titanic_df['Age_classes'].value_counts().sort_values()
# Out:
# Age_classes
# pre-teen     27
# senior       42
# infant       44
# teen         68
# old          86
# matureII    155
# adult       162
# mature      285
# Name: count, dtype: int64

# %%
titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone Age_classes
# 0    man        True  Southampton    no  False       adult
# 1  woman       False    Cherbourg   yes  False    matureII
# 2  woman       False  Southampton   yes   True      mature
# 3  woman       False  Southampton   yes  False    matureII
# 4    man        True  Southampton    no   True    matureII

# %% [markdown]
# Need to find out which how many infants survived or not survived

# %%
titanic_df.groupby(['Age_classes', 'survived']).count()
# Out:
# C:\Users\Ghazi ali\AppData\Local\Temp\ipykernel_11768\475045192.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic_df.groupby(['Age_classes', 'survived']).count()
#                       pclass  sex  age  sibsp  parch  fare  embarked  class  \
# Age_classes survived
# infant      0             13   13   13     13     13    13        13     13
#             1             31   31   31     31     31    31        31     31
# pre-teen    0             16   16   16     16     16    16        16     16
#             1             11   11   11     11     11    11        11     11
# teen        0             40   40   40     40     40    40        40     40
#             1             28   28   28     28     28    28        28     28
# ...

# %%
# Assuming 'Age_classes' and 'survived' are columns in your DataFrame
result = titanic_df.pivot_table(
    index='Age_classes', columns='survived', aggfunc='size', fill_value=0)

# Display the result
print(result)
# Out:
# survived       0   1
# Age_classes
# infant        13  31
# pre-teen      16  11
# teen          40  28
# adult        108  54
# mature       191  94
# matureII      86  69
# old           53  33
# senior        25  17

# %%
# 1 represents survived in this example
infant_survived_count = result.loc['infant', 1]
print(f"Number of infants who survived: {infant_survived_count}")
# Out:
# Number of infants who survived: 31

# %% [markdown]
# ## Filtering dataset

# %%
df_01 = titanic_df[['age', 'embark_town', 'fare', 'Age_classes', 'class']]
df_01
# Out:
#            age  embark_town     fare Age_classes   class
# 0    22.000000  Southampton   7.2500       adult   Third
# 1    38.000000    Cherbourg  71.2833    matureII   First
# 2    26.000000  Southampton   7.9250      mature   Third
# 3    35.000000  Southampton  53.1000    matureII   First
# 4    35.000000  Southampton   8.0500    matureII   Third
# ..         ...          ...      ...         ...     ...
# 886  27.000000  Southampton  13.0000      mature  Second
# 887  19.000000  Southampton  30.0000       adult   First
# 888  29.699118  Southampton  23.4500      mature   Third
# 889  26.000000    Cherbourg  30.0000      mature   First
# 890  32.000000   Queenstown   7.7500    matureII   Third
#
# [891 rows x 5 columns]

# %% [markdown]
# ## Filtering through rows

# %% [markdown]
# I want only those rows which were travelling in first class

# %%
df_01[df_01['class'] == 'First']
# Out:
#       age  embark_town     fare Age_classes  class
# 1    38.0    Cherbourg  71.2833    matureII  First
# 3    35.0  Southampton  53.1000    matureII  First
# 6    54.0  Southampton  51.8625      senior  First
# 11   58.0  Southampton  26.5500      senior  First
# 23   28.0  Southampton  35.5000      mature  First
# ..    ...          ...      ...         ...    ...
# 871  47.0  Southampton  52.5542         old  First
# 872  33.0  Southampton   5.0000    matureII  First
# 879  56.0    Cherbourg  83.1583      senior  First
# 887  19.0  Southampton  30.0000       adult  First
# 889  26.0    Cherbourg  30.0000      mature  First
#
# [216 rows x 5 columns]

# %% [markdown]
# select those rows who have paid more than 200 pounds

# %%
df_200 = df_01[(df_01['fare'] > 200) & ( df_01['age'] > 25) ]

# %%
df_200['c'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Ghazi ali\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'c'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# d:\Pandas\EDA1.ipynb Cell 54 line 1
# ...
