# %% [markdown]
# # How to find the pandas version

# %%
import pandas as pd
pd.__version__
# Out:
# '2.1.3'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit              : 2a953cf80b77e4348bf50ed724f8abc0d814d9dd
# python              : 3.10.0.final.0
# python-bits         : 64
# OS                  : Windows
# OS-release          : 10
# Version             : 10.0.19045
# machine             : AMD64
# processor           : Intel64 Family 6 Model 58 Stepping 9, GenuineIntel
# byteorder           : little
# LC_ALL              : None
# LANG                : None
# LOCALE              : English_United States.1252
#
# pandas              : 2.1.3
# numpy               : 1.26.2
# pytz                : 2023.3.post1
# dateutil            : 2.8.2
# setuptools          : 68.2.0
# pip                 : 23.2.1
# Cython              : None
# pytest              : None
# hypothesis          : None
# sphinx              : None
# blosc               : None
# feather             : None
# xlsxwriter          : None
# lxml.etree          : None
# html5lib            : None
# pymysql             : None
# psycopg2            : None
# jinja2              : None
# IPython             : 8.17.2
# pandas_datareader   : None
# bs4                 : None
# bottleneck          : None
# dataframe-api-compat: None
# fastparquet         : None
# fsspec              : None
# gcsfs               : None
# matplotlib          : 3.8.1
# numba               : None
# numexpr             : None
# odfpy               : None
# openpyxl            : None
# pandas_gbq          : None
# pyarrow             : None
# pyreadstat          : None
# pyxlsb              : None
# s3fs                : None
# scipy               : None
# sqlalchemy          : None
# tables              : None
# tabulate            : None
# xarray              : None
# xlrd                : None
# zstandard           : None
# tzdata              : 2023.3
# qtpy                : None
# pyqt5               : None

# %% [markdown]
# # How to make a dataframe

# %% [markdown]
#  1. Through Dictionary

# %%
pd.DataFrame({"A":[1,2,3,4],"B":[5,6,7,8]})
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %% [markdown]
# 2. Through numpy array

# %%
import numpy as np

# %%
pd.DataFrame(np.array([[1,3,4],[2,4,3]]))
# Out:
#    0  1  2
# 0  1  3  4
# 1  2  4  3

# %%
pd.DataFrame(np.random.rand(10,6),columns=list("ABCDEF"))
# Out:
#           A         B         C         D         E         F
# 0  0.027216  0.616457  0.141035  0.117653  0.221471  0.665513
# 1  0.998174  0.746574  0.310114  0.241121  0.491955  0.301976
# 2  0.824480  0.656933  0.850390  0.788779  0.717356  0.305232
# 3  0.539427  0.807929  0.107640  0.260337  0.793586  0.931631
# 4  0.430719  0.042376  0.280808  0.991583  0.701536  0.108329
# 5  0.012405  0.088368  0.950759  0.683085  0.988663  0.820417
# 6  0.502635  0.720497  0.942582  0.022421  0.302305  0.140132
# 7  0.607438  0.521910  0.283162  0.669587  0.582660  0.988227
# 8  0.050964  0.722353  0.417025  0.656021  0.955997  0.354875
# 9  0.653602  0.175379  0.379078  0.728287  0.865133  0.510220

# %% [markdown]
# # How to rename columns

# %%
column_example = pd.DataFrame({"A col":[1,2,3,45],"B col":[4,2,34,4]})
column_example
# Out:
#    A col  B col
# 0      1      4
# 1      2      2
# 2      3     34
# 3     45      4

# %% [markdown]
# 1. Using pd rename function

# %%
column_example = column_example.rename(columns={"A col":"A_col","B col":"B_col"})
column_example

# OR you can do like this
# column_example.rename(columns={"A col":"A_col","B col":"B_col"},inplace=True)
# Out:
#    A_col  B_col
# 0      1      4
# 1      2      2
# 2      3     34
# 3     45      4

# %%
# It will replace the first occurance column names
# with the new column names
column_example.columns = ['col_A','col_B']
column_example
# Out:
#    col_A  col_B
# 0      1      4
# 1      2      2
# 2      3     34
# 3     45      4

# %% [markdown]
# Replace any character or string

# %%
# Like let say it is written in columns col_A , col_B but we want only colA and colB
df = pd.DataFrame({"colA_":[2,4,45,3],"colB_":[2,3,4,5]})

df.columns = df.columns.str.replace("_"," ")
df
# Out:
#    colA   colB
# 0      2      2
# 1      4      3
# 2     45      4
# 3      3      5

# %% [markdown]
#  Adding suffix and prefix

# %%
df
# Out:
#    colA   colB
# 0      2      2
# 1      4      3
# 2     45      4
# 3      3      5

# %%
df = df.add_prefix("baba_")
df

# df = df.add_suffix("baba_")
# df
# Out:
#    baba_colA   baba_colB
# 0           2           2
# 1           4           3
# 2          45           4
# 3           3           5

# %% [markdown]
# # Using Template data

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# # Reverse Row Order

# %%
#  ::-1 do reverse the rows

# Also note that it reverses the indexs, the virtual counting by df
tips.loc[::-1].head()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 243       18.78  3.00  Female     No  Thur  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 239       29.03  5.92    Male     No   Sat  Dinner     3

# %% [markdown]
# Reversing the rows data and resetting the index (virtual counting)

# %%
# In this we reverse the rows also reset the indexs too, as you can see starting from 0 to n
tips.loc[::-1].reset_index(drop=True).head()
# Out:
#    total_bill   tip     sex smoker   day    time  size
# 0       18.78  3.00  Female     No  Thur  Dinner     2
# 1       17.82  1.75    Male     No   Sat  Dinner     2
# 2       22.67  2.00    Male    Yes   Sat  Dinner     2
# 3       27.18  2.00  Female    Yes   Sat  Dinner     2
# 4       29.03  5.92    Male     No   Sat  Dinner     3

# %% [markdown]
# # Reverse column order

# %% [markdown]
# loc [rows,columns]   if we say loc[::-1] means reverse the rows
# if we say loc[:,::-1] means reverse the columns
# if we say loc[::-1,::-1] means reverse rows and columns
#
# lastly loc[::-1,::-1].reset_index(drop=True)  makes the counting index from 0 onwards

# %%
# [start,stop,jump]
tips.loc[::-1,::-1].reset_index(drop=True).head()
# Out:
#    size    time   day smoker     sex   tip  total_bill
# 0     2  Dinner  Thur     No  Female  3.00       18.78
# 1     2  Dinner   Sat     No    Male  1.75       17.82
# 2     2  Dinner   Sat    Yes    Male  2.00       22.67
# 3     2  Dinner   Sat    Yes  Female  2.00       27.18
# 4     3  Dinner   Sat     No    Male  5.92       29.03

# %% [markdown]
# # Select columns by Data types

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.select_dtypes(include=["category"]).head()
# Out:
#       sex smoker  day    time
# 0  Female     No  Sun  Dinner
# 1    Male     No  Sun  Dinner
# 2    Male     No  Sun  Dinner
# 3    Male     No  Sun  Dinner
# 4  Female     No  Sun  Dinner

# %%
# selecting multiple data types columns
tips.select_dtypes(include=["category","float64"]).head()
# Out:
#    total_bill   tip     sex smoker  day    time
# 0       16.99  1.01  Female     No  Sun  Dinner
# 1       10.34  1.66    Male     No  Sun  Dinner
# 2       21.01  3.50    Male     No  Sun  Dinner
# 3       23.68  3.31    Male     No  Sun  Dinner
# 4       24.59  3.61  Female     No  Sun  Dinner

# %%
tips.select_dtypes(exclude=["category","float64"]).head()
# Out:
#    size
# 0     2
# 1     3
# 2     3
# 3     2
# 4     4

# %% [markdown]
# Sometimes we get some columns having dtypes as object but they are int64
# we then convert their datatypes to int like this

# %%
col_dtypesdf = pd.DataFrame({"col_A":['2','3','4'],"col_B":['2','3','6']})
col_dtypesdf
# Out:
#   col_A col_B
# 0     2     2
# 1     3     3
# 2     4     6

# %%
col_dtypesdf.dtypes
# Out:
# col_A    object
# col_B    object
# dtype: object

# %%
col_dtypesdf.astype({"col_A":"int64","col_B":"int64"}).dtypes
# Out:
# col_A    int64
# col_B    int64
# dtype: object

# %% [markdown]
# # Reduce dataframe size

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.sample(frac=0.5).shape # 50% rows of the data set
# Out:
# (122, 7)

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# # Copy data from clipboard

# %%
clipboardDf = pd.read_clipboard()
clipboardDf
# Out:
# Empty DataFrame
# Columns: [ship['age_group'], =, pd.cut(ship['age'],, bins=bins,, labels=labels)]
# Index: []

# %% [markdown]
# # Split data set into 2 dataframe

# %%
ship = sns.load_dataset('titanic')
ship.shape
# Out:
# (891, 15)

# %%
ship1 = ship.sample(frac=0.5,random_state=1)
ship1.shape
# Out:
# (446, 15)

# %%
ship1.head()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 862         1       1  female  48.0      0      0  25.9292        S   First
# 223         0       3    male   NaN      0      0   7.8958        S   Third
# 84          1       2  female  17.0      0      0  10.5000        S  Second
# 680         0       3  female   NaN      0      0   8.1375        Q   Third
# 535         1       2  female   7.0      0      2  26.2500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 862  woman       False    D  Southampton   yes   True
# 223    man        True  NaN  Southampton    no   True
# 84   woman       False  NaN  Southampton   yes   True
# 680  woman       False  NaN   Queenstown    no   True
# 535  child       False  NaN  Southampton   yes  False

# %% [markdown]
# making ship 2 with those index which are not in ship 1

# %%
ship2 = ship.drop(ship1.index)
ship2.shape
# Out:
# (445, 15)

# %%
ship2.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 15         1       2  female  55.0      0      0  16.0000        S  Second
# 18         0       3  female  31.0      1      0  18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# 7   child       False  NaN  Southampton    no  False
# 10  child       False    G  Southampton   yes  False
# 15  woman       False  NaN  Southampton   yes   True
# 18  woman       False  NaN  Southampton    no  False

# %% [markdown]
# # Append 2 datasets into 1

# %%
append_ship = pd.concat([ship1, ship2])

len(append_ship)
# Out:
# 891

# %% [markdown]
# # Filtering data

# %%
ship
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
ship.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
ship.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %% [markdown]
# getting data for males only

# %%
ship[(ship.sex=="male")].head()
# Out:
#    survived  pclass   sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3  male  22.0      1      0   7.2500        S  Third    man
# 4         0       3  male  35.0      0      0   8.0500        S  Third    man
# 5         0       3  male   NaN      0      0   8.4583        Q  Third    man
# 6         0       1  male  54.0      0      0  51.8625        S  First    man
# 7         0       3  male   2.0      3      1  21.0750        S  Third  child
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 4        True  NaN  Southampton    no   True
# 5        True  NaN   Queenstown    no   True
# 6        True    E  Southampton    no   True
# 7       False  NaN  Southampton    no  False

# %% [markdown]
# How many people were from southhamten

# %%
ship.embark_town.unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown', nan], dtype=object)

# %%
ship[(ship.embark_town=="Southampton")].shape
# Out:
# (644, 15)

# %%
ship[((ship.embark_town=="Southampton") | 
     (ship.embark_town=="Queenstown")) &
     (ship.sex=="female")
     ]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 11          1       1  female  58.0      0      0  26.5500        S   First
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 882         0       3  female  22.0      0      0  10.5167        S   Third
# 885         0       3  female  39.0      0      5  29.1250        Q   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 8    woman       False  NaN  Southampton   yes  False
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 880  woman       False  NaN  Southampton   yes  False
# 882  woman       False  NaN  Southampton    no   True
# 885  woman       False  NaN   Queenstown    no  False
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
#
# [239 rows x 15 columns]

# %%
ship[(ship.embark_town.isin(["Queenstown"]))].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 5          0       3    male   NaN      0      0   8.4583        Q  Third
# 16         0       3    male   2.0      4      1  29.1250        Q  Third
# 22         1       3  female  15.0      0      0   8.0292        Q  Third
# 28         1       3  female   NaN      0      0   7.8792        Q  Third
# 32         1       3  female   NaN      0      0   7.7500        Q  Third
#
#       who  adult_male deck embark_town alive  alone
# 5     man        True  NaN  Queenstown    no   True
# 16  child       False  NaN  Queenstown    no  False
# 22  child       False  NaN  Queenstown   yes   True
# 28  woman       False  NaN  Queenstown   yes   True
# 32  woman       False  NaN  Queenstown   yes   True

# %%
ship[(ship.age > 30)].shape
# Out:
# (305, 15)

# %% [markdown]
# # Filtering by large categories

# %%
ship.embark_town.value_counts()
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %% [markdown]
# # Splitting a string in multiple columns

# %%
df = pd.DataFrame({"Name":["Ahmed rasoli","Ghazi Ali","Sara Khan"],"Location":["Karachi, Pakistan","Dallas, USA","Lahore, Pakistan"]})
df
# Out:
#            Name           Location
# 0  Ahmed rasoli  Karachi, Pakistan
# 1     Ghazi Ali        Dallas, USA
# 2     Sara Khan   Lahore, Pakistan

# %%
df[["First_name","Last_name"]] = df.Name.str.split(" ",expand=True)
df
# Out:
#            Name           Location First_name Last_name
# 0  Ahmed rasoli  Karachi, Pakistan      Ahmed    rasoli
# 1     Ghazi Ali        Dallas, USA      Ghazi       Ali
# 2     Sara Khan   Lahore, Pakistan       Sara      Khan

# %% [markdown]
# quiz: Now split location in city and country

# %%
df[["City","Country"]] = df.Location.str.split(" ",expand=True)
df
# Out:
#            Name           Location First_name Last_name      City   Country
# 0  Ahmed rasoli  Karachi, Pakistan      Ahmed    rasoli  Karachi,  Pakistan
# 1     Ghazi Ali        Dallas, USA      Ghazi       Ali   Dallas,       USA
# 2     Sara Khan   Lahore, Pakistan       Sara      Khan   Lahore,  Pakistan

# %% [markdown]
# We can only take those columns that we need by doing this:

# %%
df = df[["First_name","Last_name","City","Country"]]
df
# Out:
#   First_name Last_name      City   Country
# 0      Ahmed    rasoli  Karachi,  Pakistan
# 1      Ghazi       Ali   Dallas,       USA
# 2       Sara      Khan   Lahore,  Pakistan

# %%
ship.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Aggeragate by Group function

# %%
ship.groupby('who').count()
# Out:
#        survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# who
# child        83      83   83   83     83     83    83        83     83
# man         537     537  537  413    537    537   537       537    537
# woman       271     271  271  218    271    271   271       269    271
#
#        adult_male  deck  embark_town  alive  alone
# who
# child          83    13           83     83     83
# man           537    99          537    537    537
# woman         271    91          269    271    271

# %%
ship.groupby('class',observed=True).count()
# Out:
#         survived  pclass  sex  age  sibsp  parch  fare  embarked  who  \
# class
# First        216     216  216  186    216    216   216       214  216
# Second       184     184  184  173    184    184   184       184  184
# Third        491     491  491  355    491    491   491       491  491
#
#         adult_male  deck  embark_town  alive  alone
# class
# First          216   175          214    216    216
# Second         184    16          184    184    184
# Third          491    12          491    491    491

# %% [markdown]
# len shows the category counts

# %%
len(ship.groupby('who'))
# Out:
# 3

# %%
ship.groupby(['sex','pclass']).count()
# Out:
#                survived  age  sibsp  parch  fare  embarked  class  who  \
# sex    pclass
# female 1             94   85     94     94    94        92     94   94
#        2             76   74     76     76    76        76     76   76
#        3            144  102    144    144   144       144    144  144
# male   1            122  101    122    122   122       122    122  122
#        2            108   99    108    108   108       108    108  108
#        3            347  253    347    347   347       347    347  347
#
#                adult_male  deck  embark_town  alive  alone
# sex    pclass
# female 1               94    81           92     94     94
#        2               76    10           76     76     76
#        3              144     6          144    144    144
# male   1              122    94          122    122    122
#        2              108     6          108    108    108
#        3              347     6          347    347    347

# %%
ship[['sex','pclass']].groupby(['sex','pclass']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(female, 1), (female, 2), (female, 3), (male, 1), (male, 2), (male, 3)]

# %% [markdown]
# # Select specific rows and columns

# %%
ship.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ship[['sex','class']]
# Out:
#         sex   class
# 0      male   Third
# 1    female   First
# 2    female   Third
# 3    female   First
# 4      male   Third
# ..      ...     ...
# 886    male  Second
# 887  female   First
# 888  female   Third
# 889    male   First
# 890    male   Third
#
# [891 rows x 2 columns]

# %% [markdown]
# selecting specific rows from describe function

# %%
ship.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Basically loc is [row,columns] so if we specify the rows in list that will come and leave
# the columns section it will bring all columns

# %%
# Only specified the rows so all columns are coming
ship.describe().loc[['count','mean','std']]
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429

# %%
ship.describe().loc[['count','mean','std'],['survived','pclass','age']]
# Out:
#          survived      pclass         age
# count  891.000000  891.000000  714.000000
# mean     0.383838    2.308642   29.699118
# std      0.486592    0.836071   14.526497

# %% [markdown]
# specifying the range of rows and columns

# %%
ship.describe().loc['count':'25%']
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400

# %%
ship.describe().loc['count':'25%','survived':'sibsp']
# Out:
#          survived      pclass         age       sibsp
# count  891.000000  891.000000  714.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008
# std      0.486592    0.836071   14.526497    1.102743
# min      0.000000    1.000000    0.420000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000

# %% [markdown]
# # Reshape multiIndex series

# %%
ship.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ship.age.mean()
# Out:
# 29.69911764705882

# %%
ship.groupby('sex').survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
ship.groupby(['sex','pclass']).survived.mean().unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # Making categories by classes

# %%
ship[['age']]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
bins = [0,18,35,50,100]
labels = ['0-18','19-35','36-50','51-100']

# ship['age_group'] = pd.cut(ship['age'], bins=bins, labels=labels)
pd.cut(ship['age'], bins=bins, labels=labels)

ship[['age','age_group']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Courses\ML\[FreeCoursesOnline.Me] Code With Mosh - The Complete Python Course\Python\notebooks\Tips&TricksPandas.ipynb Cell 103 line 7
#       <a href='vscode-notebook-cell:/d%3A/Courses/ML/%5BFreeCoursesOnline.Me%5D%20Code%20With%20Mosh%20-%20The%20Complete%20Python%20Course/Python/notebooks/Tips%26TricksPandas.ipynb#Y204sZmlsZQ%3D%3D?line=3'>4</a> # ship['age_group'] = pd.cut(ship['age'], bins=bins, labels=labels)
#       <a href='vscode-notebook-cell:/d%3A/Courses/ML/%5BFreeCoursesOnline.Me%5D%20Code%20With%20Mosh%20-%20The%20Complete%20Python%20Course/Python/notebooks/Tips%26TricksPandas.ipynb#Y204sZmlsZQ%3D%3D?line=4'>5</a> pd.cut(ship['age'], bins=bins, labels=labels)
# ----> <a href='vscode-notebook-cell:/d%3A/Courses/ML/%5BFreeCoursesOnline.Me%5D%20Code%20With%20Mosh%20-%20The%20Complete%20Python%20Course/Python/notebooks/Tips%26TricksPandas.ipynb#Y204sZmlsZQ%3D%3D?line=6'>7</a> ship[['age','age_group']]
#
# File c:\Users\USER\.virtualenvs\v1.0-4BS-EnEY\lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\USER\.virtualenvs\v1.0-4BS-EnEY\lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File c:\Users\USER\.virtualenvs\v1.0-4BS-EnEY\lib\site-packages\pandas\core\indexes\base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['age_group'] not in index"

# %%
ship.groupby(['age_group','sex'],observed=True).count()
# Out:
#                   survived  pclass  age  sibsp  parch  fare  embarked  class  \
# age_group sex
# 0-18      female        68      68   68     68     68    68        68     68
#           male          71      71   71     71     71    71        71     71
# 19-35     female       120     120  120    120    120   120       120    120
#           male         238     238  238    238    238   238       238    238
# 36-50     female        56      56   56     56     56    56        55     56
#           male          97      97   97     97     97    97        97     97
# 51-100    female        17      17   17     17     17    17        16     17
#           male          47      47   47     47     47    47        47     47
#
#                   who  adult_male  deck  embark_town  alive  alone
# age_group sex
# 0-18      female   68          68    14           68     68     68
#           male     71          71     9           71     71     71
# 19-35     female  120         120    39          120    120    120
#           male    238         238    28          238    238    238
# 36-50     female   56          56    24           55     56     56
#           male     97          97    37           97     97     97
# 51-100    female   17          17    13           16     17     17
#           male     47          47    20           47     47     47

# %% [markdown]
# # Assigning numerical value to categories for analysis

# %%
ship.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone age_group
# 0    man        True  NaN  Southampton    no  False     19-35
# 1  woman       False    C    Cherbourg   yes  False     36-50
# 2  woman       False  NaN  Southampton   yes   True     19-35
# 3  woman       False    C  Southampton   yes  False     19-35
# 4    man        True  NaN  Southampton    no   True     19-35

# %%
ship.sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
ship['sex_numerical'] = ship.sex.map({"male":1,"female":0})
ship[['sex','sex_numerical']]
# Out:
#         sex  sex_numerical
# 0      male              1
# 1    female              0
# 2    female              0
# 3    female              0
# 4      male              1
# ..      ...            ...
# 886    male              1
# 887  female              0
# 888  female              0
# 889    male              1
# 890    male              1
#
# [891 rows x 2 columns]

# %% [markdown]
# now using factorise we can assign numerical values to a category

# %%
# Like the category embarked
ship.embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
ship['embarked_num'] = ship.embarked.factorize()[0]
ship[['embarked','embarked_num']]
# Out:
#     embarked  embarked_num
# 0          S             0
# 1          C             1
# 2          S             0
# 3          S             0
# 4          S             0
# ..       ...           ...
# 886        S             0
# 887        S             0
# 888        S             0
# 889        C             1
# 890        Q             2
#
# [891 rows x 2 columns]

# %% [markdown]
# # Transpose a wide dataframe

# %% [markdown]
# convert rows into columns and columns into rows

# %%
df = pd.DataFrame(np.random.rand(500,10),columns=list("ABCDEFGHIJ"))
df
# Out:
#             A         B         C         D         E         F         G  \
# 0    0.965821  0.471204  0.815514  0.992348  0.736391  0.124154  0.299690
# 1    0.994409  0.281178  0.699226  0.873264  0.537672  0.967397  0.555691
# 2    0.032317  0.805638  0.318802  0.568857  0.121264  0.723015  0.504618
# 3    0.226665  0.370535  0.479407  0.613343  0.077285  0.778698  0.457059
# 4    0.409164  0.810423  0.424924  0.388157  0.908294  0.599484  0.484777
# ..        ...       ...       ...       ...       ...       ...       ...
# 495  0.872467  0.177536  0.681851  0.133154  0.445412  0.220758  0.349212
# 496  0.333075  0.725477  0.490474  0.157725  0.625579  0.614478  0.181235
# 497  0.320465  0.475047  0.895662  0.519213  0.627178  0.252777  0.717441
# 498  0.419316  0.264254  0.872350  0.691618  0.188214  0.519997  0.154522
# 499  0.897441  0.370153  0.021151  0.956497  0.787527  0.456895  0.753790
#
#             H         I         J
# 0    0.255686  0.216809  0.266364
# 1    0.699900  0.984862  0.535940
# 2    0.713782  0.963655  0.718900
# 3    0.595081  0.670906  0.705827
# 4    0.204177  0.676966  0.802901
# ..        ...       ...       ...
# 495  0.147035  0.797485  0.074870
# 496  0.778206  0.894803  0.278873
# 497  0.796653  0.562671  0.871021
# 498  0.079428  0.293522  0.798198
# 499  0.188180  0.693696  0.344314
#
# [500 rows x 10 columns]

# %% [markdown]
# As you can see it's not easy to read like this so we can Transform it

# %%
df.describe()
# Out:
#                 A           B           C           D           E           F  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.518645    0.520037    0.508380    0.512561    0.513789    0.505780
# std      0.282209    0.278902    0.281261    0.293152    0.285354    0.291032
# min      0.001108    0.000189    0.005553    0.000063    0.001372    0.000786
# 25%      0.263141    0.263701    0.276080    0.240730    0.276148    0.249686
# 50%      0.518366    0.528085    0.523011    0.532722    0.511325    0.511562
# 75%      0.770190    0.754123    0.752913    0.774962    0.774763    0.750247
# max      0.998054    0.995202    0.996602    0.998337    0.999108    0.998824
#
#                 G           H           I           J
# count  500.000000  500.000000  500.000000  500.000000
# mean     0.487433    0.474546    0.495520    0.489450
# std      0.291139    0.298318    0.290524    0.287453
# min      0.000106    0.004498    0.009152    0.000866
# 25%      0.233657    0.189262    0.231901    0.243392
# 50%      0.480019    0.489563    0.496186    0.488999
# 75%      0.744660    0.753876    0.758161    0.732481
# max      0.998668    0.998448    0.999512    0.998732

# %% [markdown]
# Transform the rows in columns and columns in rows

# %%
df.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# A  500.0  0.518645  0.282209  0.001108  0.263141  0.518366  0.770190  0.998054
# B  500.0  0.520037  0.278902  0.000189  0.263701  0.528085  0.754123  0.995202
# C  500.0  0.508380  0.281261  0.005553  0.276080  0.523011  0.752913  0.996602
# D  500.0  0.512561  0.293152  0.000063  0.240730  0.532722  0.774962  0.998337
# E  500.0  0.513789  0.285354  0.001372  0.276148  0.511325  0.774763  0.999108
# F  500.0  0.505780  0.291032  0.000786  0.249686  0.511562  0.750247  0.998824
# G  500.0  0.487433  0.291139  0.000106  0.233657  0.480019  0.744660  0.998668
# H  500.0  0.474546  0.298318  0.004498  0.189262  0.489563  0.753876  0.998448
# I  500.0  0.495520  0.290524  0.009152  0.231901  0.496186  0.758161  0.999512
# J  500.0  0.489450  0.287453  0.000866  0.243392  0.488999  0.732481  0.998732
